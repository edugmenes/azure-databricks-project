# %%
# %sql
-- Dropping any existant catalog schema
DROP SCHEMA IF EXISTS bike_store.resource;

# %%
# %sql
-- Creatiing a new schema to run the project
CREATE SCHEMA IF NOT EXISTS bike_store.resource_schema;

-- Creating an external volume to access azure origin CSVs
CREATE EXTERNAL VOLUME IF NOT EXISTS bike_store.resource_schema.resouce
COMMENT 'External volume created to access azure external resource directory'
LOCATION 'abfss://container20260122@datalake20260121.dfs.core.windows.net/resource';
